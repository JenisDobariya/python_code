# %% [markdown]
# <a href="https://colab.research.google.com/github/JenisDobariya/python_code/blob/main/Answer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Preprocessing and Spam Detection
# •	Rule-based AI
# •	Data Preprocessing
# •	Encoding: One-hot encoding, Bag of Words
# •	Spam Detection using BoWs
# •	Spam Detection using Linear Regression
# •	Spam Detection using KNN
# •	Performance Metrics
# Data Preprocessing

# Task 1 — Load and Inspect the Dataset
import pandas as pd
import numpy as np
df = pd.read_csv("spam_dataset.csv")
#OR
df = pd.read_excel("spam_dataset.xlsx")
df.head()
df.info()

# Task 2 — Handle Missing Values : Numeric Columns → Mean
df = df.fillna(df.mean())

# Task 3 — Handle Outliers (Replace with Mean)
df = df.apply(lambda x: x.where((x - x.mean()).abs() <= 3 * x.std(), x.mean())

# Task 4 — Normalization
# Min–Max Scaling:
df = (df - df.min()) / (df.max() - df.min())

# Feature Encoding
# Task 5 — Identify Categorical Columns
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["label"] = le.fit_transform(df["label"])

# Task 6A — One-Hot Encoding
df = pd.get_dummies(df)
# OR
pd.get_dummies(df['column_name'])
pd.get_dummies(df['category'])

# Task 6B — Bag-of-Words Encoding
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
bow = cv.fit_transform(df["text"])

# Spam Detection Pipeline
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Machine Learning Models
# Linear Regression:
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# OR

y_pred = (lr.predict(X_test) >= 0.5).astype(int)
accuracy_score(y_test, y_pred)

# KNN Classification:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred= knn.predict(X_test)
print("KNN Accuracy:", accuracy_score(y_test, y_pred))

# Questions :
# 1.	Which model performed better? Why?
# 2.	How does normalization affect the accuracy of a model?
# 3.	How does Natural Language Processing (NLP) contribute to cybersecurity, particularly in detecting spam, phishing messages, malicious URLs, or other text-based cyber threats?
# 4.	Before using ML and NLP models, simple rule-based AI (if–else conditions) is often used for cybersecurity tasks such as detecting suspicious messages or URLs. What are the limitations of rule-based systems in cybersecurity, and why do we eventually shift to ML/NLP-based models?
